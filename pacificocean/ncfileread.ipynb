# %%
from scipy.io import netcdf

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
path = 'E:/표층수온자료/G1SST/nc/'
file2read = netcdf.NetCDFFile(path+'20100609-JPL_OUROCEAN-L4UHfnd-GLOB-v01-fv01_0-G1SST.cut.nc','r')

# %%
temp = file2read.variables[var]
data = temp[:]*1

# %%
file2read.close()

# %%
plt.contourf(data[t,z,:,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-65cc39834067> in <module>
# ----> 1 plt.contourf(data[t,z,:,:])
#
# NameError: name 'data' is not defined

# %%
from matplotlib import pyplot as plt
import pandas as pd
import netCDF4

# %%
# !pip install pandas
# Out:
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
# !pip install netCDF4
# Out:
# ...
#   Using cached netCDF4-1.5.3-cp37-cp37m-win_amd64.whl (3.1 MB)
# ...
#   Using cached cftime-1.1.0-cp37-none-win_amd64.whl (212 kB)
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
fp = 'E:/sst/G1SST/nc/20100621-JPL_OUROCEAN-L4UHfnd-GLOB-v01-fv01_0-G1SST.cut.nc'
nc = netCDF4.Dataset(fp)
import matplotlib.image as mpimg
img = mpimg.imread('E:/sst/G1SST/png/20100621-JPL_OUROCEAN-L4UHfnd-GLOB-v01-fv01_0-G1SST.cut.png')
plt.imshow(img)
plt.show()

# %%
print(nc)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)
#     Conventions: CF-1.0
#     history: Mon Mar 18 09:19:11 2019: cdo sellonlatbox,110,150,20,50 20100621-JPL_OUROCEAN-L4UHfnd-GLOB-v01-fv01_0-G1SST.nc ./cut/20100621-JPL_OUROCEAN-L4UHfnd-GLOB-v01-fv01_0-G1SST.cut.nc
# 1km SST blended from 8 satellite observations
#     institution: Jet Propulsion Laboratory, The OurOcean Team
#     title: G1SST, 1km blended SST
#     DSD_entry_id: JPL_OUROCEAN-L4UHfnd-GLOB-G1SST
#     references: A Blended Global 1-km Sea Surface Temperature Data Set for Research and Applications
# by Yi Chao, Benyang Tang, Zhijin Li, Peggy Li, Quoc Vu
#     contact: yi.chao@jpl.nasa.gov
#     GDS_version_id: v1.0-rev1.7
#     netcdf_version_id: 3.6.0
#     creation_date: 2010-06-23 UTC
#     product_version: 1.0
#     spatial_resolution: 1 km
# ...

# %%
print(nc.variables.keys())
# Out:
# dict_keys(['time', 'lon', 'lat', 'analysed_sst', 'mask', 'analysis_error'])

# %%
nc_value = nc.variables.keys()

# %%
nc_lat = nc.variables[u'lat'][:]
nc_lon = nc.variables[u'lon'][:]

# %%
nc_time = nc.variables[u'time'][:]
nc_mask = nc.variables[u'mask'][:]
nc_analysed_sst = nc.variables[u'analysed_sst'][:]
nc_analysis_error = nc.variables[u'analysis_error'][:]

# %%
ostia_fp = 'E:/sst/OSTIA/nc/20060401-UKMO-L4HRfnd-GLOB-v01-fv02-OSTIA.cut.nc'
ostia_nc = netCDF4.Dataset(ostia_fp)

ostia_img = mpimg.imread('E:/sst/OSTIA/png/20060401-UKMO-L4HRfnd-GLOB-v01-fv02-OSTIA.cut.png')
plt.imshow(ostia_img)
plt.show()

# %%
ostia_nc.variables.keys()
# Out:
# dict_keys(['time', 'lon', 'lat', 'analysed_sst', 'analysis_error', 'sea_ice_fraction', 'mask'])

# %%
dep = [0,10,25,50,75]
depnum = [18,16,15,13,12]

for i in range(0,1,1):
    depcount = -1
    for j in depnum:
        print(j)
        depcount += 1
        fig = plt.figure(figsize=(10,12.5))
        az = fig.add_subplot(111)
        
        plt.style.use('seaborn-darkgrid')
        
        plt.rc("font",size=15)
        plt.rcParams['font.family'] = 'sans-serif'
        plt.rcParams['font.sans-serif'] = 'New Century Schoolbook'
        plt.rcParams['font.weight'] = 'bold'
        plt.rcParams['axes.labelsize'] = 26
        plt.rcParams['xtick.labelsize'] = 26
        plt.rcParams['ytick.labelsize'] = 26
        plt.rcParams['axes.labelweight'] = 'bold'
        plt.rcParams['axes.titleweight'] = 'bold'
        plt.rcParams['contour.corner_mask'] = False
        plt.rcParams.update({'figure.autolayout' : True})
        
        var = nc.variables[u'temperature'][i, j, :, :]
        var = switch(var, j)
        var = np.ma.array(var, mask=var <= 0.0)
        
        cc = plt.contour(B5_x, B5_y,var,tp_cont_tick, linewidths=1, cmap = vcmap)
# Out:
# 18
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-e11aafd320fd> in <module>
#      24         plt.rcParams.update({'figure.autolayout' : True})
#      25
# ---> 26         var = nc.variables[u'temperature'][i, j, :, :]
#      27         var = switch(var, j)
#      28         var = np.ma.array(var, mask=var <= 0.0)
#
# KeyError: 'temperature'
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# !pip install folium
# Out:
# ...
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
import folium

# %%
map_a = folium.Map(location=[-60.5,118.5])

# %%
map_a
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(location=[-28.5,288.5])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([-28.5,288.5],popup='(b)').add_to(map_a)
folium.Marker([-60.5,118.5],popup='(a)').add_to(map_a)
map_a
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
