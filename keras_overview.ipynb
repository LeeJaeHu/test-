# %%
# !pip install -q pyyaml
# !pip install -q tensorflow-gpu==2.0.0-rc1
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras

# %%
# !pip install -q keras

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
print(tf.keras.__version__)
print(keras.__version__)
# Out:
# 2.2.4-tf
# 2.3.1

# %%
from tensorflow.keras import layers
model = tf.keras.Sequential()
# Adds a densely-connected layer with 64 units to the model:
model.add(layers.Dense(64, activation='relu'))
# Add another:
model.add(layers.Dense(64, activation='relu'))
# Add a softmax layer with 10 output units:
model.add(layers.Dense(10, activation='softmax'))

# %%
# !pip install pydot

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.13.2-py2.py3-none-any.whl (17 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.13.2
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
# !pip install pyparsing
# !conda install graphviz
# Out:
# Requirement already satisfied: pyparsing in c:\users\pc\anaconda3\envs\tf2.0-gpu\lib\site-packages (2.4.6)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
import pydot
import graphviz
tf.keras.utils.plot_model(model, to_file='./model.png')

# %%
#시그모이드 활성화층
layers.Dense(64, activation='sigmoid')
#또는
layers.Dense(64, activation=tf.keras.activations.sigmoid)

#커널 행렬에 L1 규제가 적용된 선형 활성화 층. 하이퍼파라미터 0.01은 규제의 양을 조절
layers.Dense(64, kernel_regularizer=tf.keras.regularizers.l1(0.01))

#커널 벡터에 L2 규제가 적용된 선형 활성화 층. 하이퍼파라미터 0.01은 규제의 양을 조절
layers.Dense(64, bias_regularizer = tf.keras.regularizers.l2(0.01))

#커널을 랜덤한 직교행렬로 초기화한 선형 활성화 층:
layers.Dense(64, kernel_initializer = 'orthogonal')

#절편 벡터를 상수 2.0으로 설정한 선형 활성화 층
layers.Dense(64, bias_initializer = tf.keras.initializers.Constant(2.0))

# %%
model1 = tf.keras.Sequential([layers.Dense(64,kernel_regularizer = 'l1')])

# %%
layers.Dense(64,kernel_regularizer = tf.keras.regularizers.l1(0.01))

# %%
print(model1.layers)
# Out:
# [<tensorflow.python.keras.layers.core.Dense object at 0x000001ECDA760088>]

# %%
model = tf.keras.Sequential([
    # Adds a densely-connected layer with 64 units to the model:
    layers.Dense(64, activation='relu', input_shape=(32,)),
    # Add another:
    layers.Dense(64, activation='relu'),
    # Add a softmax layer with 10 output units:
    layers.Dense(10, activation = 'softmax')])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.Accuracy(name='accuracy')])

# %%
logdir = './logs/fit/'
tensorboard_callback = keras.callbacks.TensorBoard(log_dir = logdir)
model.fit(
    train_images,
    train_labels,
    batch_size=64,
    epochs=5,
callbacks=[tensorboard_callback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cd6a6cf27d52> in <module>
#       2 tensorboard_callback = keras.callbacks.TensorBoard(log_dir = logdir)
#       3 model.fit(
# ----> 4     train_images,
#       5     train_labels,
#       6     batch_size=64,
#
# NameError: name 'train_images' is not defined

# %%
tf.keras.losses.CategoricalCrossentropy()

# %%
tf.keras.losses.categorical_crossentropy
# Out:
# <function tensorflow.python.keras.losses.categorical_crossentropy(y_true, y_pred, from_logits=False, label_smoothing=0)>

# %%
tf.keras.optimizers.Adam
# Out:
# tensorflow.python.keras.optimizer_v2.adam.Adam

# %%
tf.keras.metrics.Accuracy
# Out:
# tensorflow.python.keras.metrics.Accuracy

# %%
print(model.optimizer.lr)
# Out:
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>

# %%
#평균제곱오차로 회귀모델 설정
model.compile(optimizer=tf.keras.optimizers.Adam(0.01),
             loss='mse',metrics=['mae'])#평균 절댓값오차

#크로스엔트로피 손실함수로 분류모델 설정
model.compile(optimizer = tf.keras.optimizers.RMSprop(0.001),
             loss = tf.keras.losses.CategoricalCrossentropy(),
             metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
tf.__version__
# Out:
# '2.0.0-beta1'

# %%
import numpy as np

data = np.random.random((1000,32))
labels=np.random.random((1000,10))

model.fit(data, labels, epochs=10, batch_size=32)
# Out:
# Train on 1000 samples
# Epoch 1/10
# 1000/1000 [==============================] - 1s 648us/sample - loss: 14.3090 - categorical_accuracy: 0.1200
# Epoch 2/10
# 1000/1000 [==============================] - 0s 69us/sample - loss: 23.8790 - categorical_accuracy: 0.1230
# Epoch 3/10
# 1000/1000 [==============================] - 0s 71us/sample - loss: 36.3936 - categorical_accuracy: 0.1010
# Epoch 4/10
# 1000/1000 [==============================] - 0s 68us/sample - loss: 50.3499 - categorical_accuracy: 0.1080
# Epoch 5/10
# 1000/1000 [==============================] - 0s 66us/sample - loss: 68.0972 - categorical_accuracy: 0.1070
# Epoch 6/10
# 1000/1000 [==============================] - 0s 67us/sample - loss: 87.2301 - categorical_accuracy: 0.1070
# Epoch 7/10
# 1000/1000 [==============================] - 0s 67us/sample - loss: 105.2426 - categorical_accuracy: 0.1080
# Epoch 8/10
# 1000/1000 [==============================] - 0s 69us/sample - loss: 124.1385 - categorical_accuracy: 0.0950
# Epoch 9/10
# 1000/1000 [==============================] - 0s 67us/sample - loss: 141.9253 - categorical_accuracy: 0.1090
# Epoch 10/10
# 1000/1000 [==============================] - 0s 71us/sample - loss: 156.9719 - categorical_accuracy: 0.0860

# %%
data
# Out:
# array([[0.16605216, 0.3298519 , 0.21542867, ..., 0.95262938, 0.90221717,
#         0.35500088],
#        [0.32926007, 0.78565397, 0.81806572, ..., 0.41635075, 0.0425022 ,
#         0.8994664 ],
#        [0.60955539, 0.42280322, 0.90577043, ..., 0.74772559, 0.96958483,
#         0.43280727],
#        ...,
#        [0.58839915, 0.31746874, 0.72312094, ..., 0.011802  , 0.01811065,
#         0.04732801],
#        [0.57147443, 0.32917591, 0.60157149, ..., 0.1324337 , 0.26072283,
#         0.30272648],
#        [0.80193229, 0.89035403, 0.01455276, ..., 0.93494677, 0.3777997 ,
#         0.21543733]])

# %%
data = np.random.random((1000, 32))
labels = np.random.random((1000, 10))

val_data = np.random.random((100, 32))
val_labels = np.random.random((100, 10))

model.fit(data, labels, epochs=10, batch_size=32,
          validation_data=(val_data, val_labels))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/10
# 1000/1000 [==============================] - 0s 145us/sample - loss: 104.6653 - categorical_accuracy: 0.0950 - val_loss: 103.4584 - val_categorical_accuracy: 0.0900
# Epoch 2/10
# 1000/1000 [==============================] - 0s 81us/sample - loss: 108.7665 - categorical_accuracy: 0.1130 - val_loss: 97.2267 - val_categorical_accuracy: 0.1300
# Epoch 3/10
# 1000/1000 [==============================] - 0s 81us/sample - loss: 104.5011 - categorical_accuracy: 0.0870 - val_loss: 93.9268 - val_categorical_accuracy: 0.1000
# Epoch 4/10
# 1000/1000 [==============================] - 0s 83us/sample - loss: 102.1683 - categorical_accuracy: 0.0780 - val_loss: 92.9825 - val_categorical_accuracy: 0.1000
# Epoch 5/10
# 1000/1000 [==============================] - 0s 81us/sample - loss: 106.4443 - categorical_accuracy: 0.0890 - val_loss: 80.6932 - val_categorical_accuracy: 0.0800
# Epoch 6/10
# 1000/1000 [==============================] - 0s 79us/sample - loss: 93.4183 - categorical_accuracy: 0.0970 - val_loss: 87.6246 - val_categorical_accuracy: 0.1200
# Epoch 7/10
# 1000/1000 [==============================] - 0s 80us/sample - loss: 81.4287 - categorical_accuracy: 0.1050 - val_loss: 66.8805 - val_categorical_accuracy: 0.1100
# Epoch 8/10
# 1000/1000 [==============================] - 0s 78us/sample - loss: 57.4420 - categorical_accuracy: 0.0970 - val_loss: 37.2775 - val_categorical_accuracy: 0.1000
# Epoch 9/10
# 1000/1000 [==============================] - 0s 83us/sample - loss: 51.7040 - categorical_accuracy: 0.1020 - val_loss: 79.5304 - val_categorical_accuracy: 0.1100
# Epoch 10/10
# 1000/1000 [==============================] - 0s 81us/sample - loss: 72.7627 - categorical_accuracy: 0.1080 - val_loss: 72.8686 - val_categorical_accuracy: 0.0700

# %%
# 예제 `Dataset` 객체를 만듭니다:
dataset = tf.data.Dataset.from_tensor_slices((data, labels))
dataset = dataset.batch(32)

# Dataset에서 `fit` 메서드를 호출할 때 `steps_per_epoch` 설정을 잊지 마세요.
model.fit(dataset, epochs=10)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 0s 5ms/step - loss: 177.9726 - categorical_accuracy: 0.0860
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 170.1507 - categorical_accuracy: 0.0810
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 158.2440 - categorical_accuracy: 0.0790
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 131.4636 - categorical_accuracy: 0.0900
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 88.1187 - categorical_accuracy: 0.0770
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 65.4636 - categorical_accuracy: 0.0970
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 76.8752 - categorical_accuracy: 0.0830
# Epoch 8/10
# 32/32 [==============================] - 0s 4ms/step - loss: 87.1481 - categorical_accuracy: 0.0990
# Epoch 9/10
# 32/32 [==============================] - 0s 4ms/step - loss: 90.3280 - categorical_accuracy: 0.0940
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 103.9812 - categorical_accuracy: 0.0930

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-55ab94239508> in <module>
# ----> 1 data = shuffle(data)
#
# NameError: name 'shuffle' is not defined

# %%
dataset = tf.data.Dataset.from_tensor_slices((data, labels))
dataset = dataset.batch(32)

val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
val_dataset = val_dataset.batch(32)

model.fit(dataset, epochs=10,
          validation_data=val_dataset)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 0s 9ms/step - loss: 79.4179 - categorical_accuracy: 0.0990 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/10
# 32/32 [==============================] - 0s 4ms/step - loss: 90.0333 - categorical_accuracy: 0.0890 - val_loss: 97.8298 - val_categorical_accuracy: 0.0900
# Epoch 3/10
# 32/32 [==============================] - 0s 4ms/step - loss: 94.6074 - categorical_accuracy: 0.1000 - val_loss: 98.5329 - val_categorical_accuracy: 0.1000
# Epoch 4/10
# 32/32 [==============================] - 0s 4ms/step - loss: 106.5083 - categorical_accuracy: 0.0860 - val_loss: 114.4401 - val_categorical_accuracy: 0.0800
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 127.6571 - categorical_accuracy: 0.1070 - val_loss: 83.0545 - val_categorical_accuracy: 0.1000
# Epoch 6/10
# 32/32 [==============================] - 0s 4ms/step - loss: 127.6310 - categorical_accuracy: 0.0990 - val_loss: 110.1320 - val_categorical_accuracy: 0.1000
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 124.7830 - categorical_accuracy: 0.1130 - val_loss: 120.3803 - val_categorical_accuracy: 0.1600
# Epoch 8/10
# 32/32 [==============================] - 0s 4ms/step - loss: 160.2659 - categorical_accuracy: 0.0890 - val_loss: 183.7303 - val_categorical_accuracy: 0.1000
# Epoch 9/10
# 32/32 [==============================] - 0s 4ms/step - loss: 164.9544 - categorical_accuracy: 0.0890 - val_loss: 205.0290 - val_categorical_accuracy: 0.1000
# Epoch 10/10
# 32/32 [==============================] - 0s 4ms/step - loss: 177.7129 - categorical_accuracy: 0.0990 - val_loss: 199.6053 - val_categorical_accuracy: 0.1000

# %%
# With NumPy arrays
data = np.random.random((1000, 32))
labels = np.random.random((1000, 10))

model.evaluate(data, labels, batch_size=32)

# With a Dataset
dataset = tf.data.Dataset.from_tensor_slices((data, labels))
dataset = dataset.batch(32)

model.evaluate(dataset)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 32/32 [==============================] - 0s 2ms/step - loss: 204.2633 - categorical_accuracy: 0.0850
# [204.26329135894775, 0.085]

# %%
result = model.predict(data, batch_size=32)
print(result.shape)
# Out:
# (1000, 10)
# array([[0.0000000e+00, 7.9898669e-08, 1.9704390e-31, ..., 1.0822933e-15,
#         9.7805035e-01, 2.1948224e-02],
#        [0.0000000e+00, 1.3955774e-07, 9.8252241e-30, ..., 5.5130283e-15,
#         9.8102015e-01, 1.8978002e-02],
#        [0.0000000e+00, 5.2860435e-07, 1.2518024e-27, ..., 8.1946223e-14,
#         9.5430154e-01, 4.5691721e-02],
#        ...,
#        [0.0000000e+00, 9.9343573e-08, 5.2272945e-31, ..., 1.3456908e-15,
#         9.8481005e-01, 1.5189035e-02],
#        [0.0000000e+00, 9.5997621e-07, 1.1635551e-26, ..., 1.7881027e-13,
#         9.6837234e-01, 3.1618476e-02],
#        [0.0000000e+00, 5.1317323e-07, 1.7137907e-27, ..., 4.6767410e-14,
#         9.7090435e-01, 2.9090611e-02]], dtype=float32)

# %%
inputs = tf.keras.Input(shape=(32,))  # Return an input placeholder

# A layer instance is callable on a tensor, and returns a tensor.
x = layers.Dense(64, activation='relu')(inputs)
x = layers.Dense(64, activation='relu')(x)
predictions = layers.Dense(10, activation='softmax')(x)

# %%
model = tf.keras.Model(inputs=inputs, outputs=predictions)

# The compile step specifies the training configuration.
model.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Trains for 5 epochs
model.fit(data, labels, batch_size=32, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 343us/sample - loss: 13.4173 - accuracy: 0.0900
# Epoch 2/5
# 1000/1000 [==============================] - 0s 69us/sample - loss: 20.8534 - accuracy: 0.0990
# Epoch 3/5
# 1000/1000 [==============================] - 0s 71us/sample - loss: 32.8818 - accuracy: 0.1000
# Epoch 4/5
# 1000/1000 [==============================] - 0s 69us/sample - loss: 48.3097 - accuracy: 0.0990
# Epoch 5/5
# 1000/1000 [==============================] - 0s 65us/sample - loss: 66.0171 - accuracy: 0.0960

# %%
class MyModel(tf.keras.Model):
    
    def __init__(self, num_classes=10):
        super(MyModel, self).__init__(name='my_model')
        self.num_classes = num_classes
        # Define your layers here.
        self.dense_1 = layers.Dense(32, activation='relu')
        self.dense_2 = layers.Dense(num_classes, activation='sigmoid')
        
    def call(self, inputs):
        # Define your forward pass here.
        # using layers you previously defined (in '__init__').
        x = self.dense_1(inputs)
        return self.dense_2(x)

# %%
model = MyModel(num_classes=10)

# The compile step specifies the training configuration.
model.compile(optimizer = tf.keras.optimizers.RMSprop(0.001),
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

# Trains for 5 epochs.
model.fit(data, labels, batch_size=32, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\pc\Anaconda3\envs\tf2.0-gpu\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1394: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 1000/1000 [==============================] - 0s 384us/sample - loss: 11.7733 - accuracy: 0.0960
# Epoch 2/5
# 1000/1000 [==============================] - 0s 78us/sample - loss: 11.6766 - accuracy: 0.0960
# Epoch 3/5
# 1000/1000 [==============================] - 0s 67us/sample - loss: 11.6647 - accuracy: 0.0990
# Epoch 4/5
# 1000/1000 [==============================] - 0s 72us/sample - loss: 11.6564 - accuracy: 0.1090
# Epoch 5/5
# 1000/1000 [==============================] - 0s 76us/sample - loss: 11.6506 - accuracy: 0.1020

# %%
class MyLayer(layers.Layer):
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(MyLayer, self).__init__(**kwargs)
    
    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        self.kernel = self.add_weight(name='kernel',
                                     shape=(input_shape[1], self.output_dim),
                                     initializer = 'uniform',
                                     trainable = True)
    def call(self, inputs):
        return tf.matmul(inputs, self.kernel)
    
    def get_config(self):
        base_config = super(MyLayer, self).get_config()
        base_config['output_dim'] = self.output_dim
        return base_config
    
    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %%
layers.Layer(10)

# %%
model = tf.keras.Sequential([
    MyLayer(10),
    layers.Activation('softmax')])

# The compile step specifies the training configuration
model.compile(optimizer = tf.keras.optimizers.RMSprop(0.001),
             loss = 'categorical_crossentropy',
             metrics=['accuracy'])

# Trains for 5 epochs.
model.fit(data, labels, batch_size=32, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 207us/sample - loss: 11.6573 - accuracy: 0.1160
# Epoch 2/5
# 1000/1000 [==============================] - 0s 50us/sample - loss: 11.6569 - accuracy: 0.1190
# Epoch 3/5
# 1000/1000 [==============================] - 0s 48us/sample - loss: 11.6570 - accuracy: 0.1180
# Epoch 4/5
# 1000/1000 [==============================] - 0s 48us/sample - loss: 11.6569 - accuracy: 0.1190
# Epoch 5/5
# 1000/1000 [==============================] - 0s 49us/sample - loss: 11.6567 - accuracy: 0.1190

# %%
# %load_ext tensorboard

# %%
# !rm -rf ./logs/
# Out:
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 14796), started 3 days, 9:10:23 ago. (Use '!kill 14796' to kill it.)
#       <iframe id="tensorboard-frame-a1a1cba1e5e8f72d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a1a1cba1e5e8f72d");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 3776
# Out:
# 'kill'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import os
os.getcwd()
# Out:
# 'D:\\py'

# %%
callbacks = [
    # Interrupt trining if 'val_loss' stops improving for 2 epochs
    tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'),
    # Write TensorBoard logs to './logs' directory
    tf.keras.callbacks.TensorBoard(log_dir = './logs',profile_batch=0)
]

# %%
model.fit(data, labels, batch_size = 32, epochs = 5, callbacks = callbacks,
         validation_data = (val_data, val_labels))
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 210us/sample - loss: 11.6565 - accuracy: 0.1210 - val_loss: 11.1513 - val_accuracy: 0.1000
# Epoch 2/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 11.6566 - accuracy: 0.1200 - val_loss: 11.1503 - val_accuracy: 0.0900
# Epoch 3/5
# 1000/1000 [==============================] - 0s 89us/sample - loss: 11.6567 - accuracy: 0.1160 - val_loss: 11.1499 - val_accuracy: 0.0900
# Epoch 4/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 11.6565 - accuracy: 0.1180 - val_loss: 11.1501 - val_accuracy: 0.0900
# Epoch 5/5
# 1000/1000 [==============================] - 0s 93us/sample - loss: 11.6565 - accuracy: 0.1180 - val_loss: 11.1499 - val_accuracy: 0.0900

# %%
model = tf.keras.Sequential([
layers.Dense(64, activation='relu', input_shape=(32,)),
layers.Dense(10, activation='softmax')])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Save weights to a TensorFlow Checkpoint file
model.save_weights('./weights/my_model')

# Restore the model's state,
# this requires a model with the same architecture.
model.load_weights('./weights/my_model')

# %%
# Save weights to a HDF5 file
model.save_weights('my_model.h5', save_format='h5')

# Restore the model's state
model.load_weights('my_model.h5')

# %%
# Serialize a model to JSON format
json_string = model.to_json()
json_string
# Out:
# '{"class_name": "Sequential", "config": {"name": "sequential_3", "layers": [{"class_name": "Dense", "config": {"name": "dense_11", "trainable": true, "batch_input_shape": [null, 32], "dtype": "float32", "units": 64, "activation": "relu", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Dense", "config": {"name": "dense_12", "trainable": true, "dtype": "float32", "units": 10, "activation": "softmax", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}]}, "keras_version": "2.2.4-tf", "backend": "tensorflow"}'

# %%
import json
import pprint
pprint.pprint(json.loads(json_string))
# Out:
# {'backend': 'tensorflow',
#  'class_name': 'Sequential',
#  'config': {'layers': [{'class_name': 'Dense',
#                         'config': {'activation': 'relu',
#                                    'activity_regularizer': None,
#                                    'batch_input_shape': [None, 32],
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_11',
#                                    'trainable': True,
#                                    'units': 64,
#                                    'use_bias': True}},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'softmax',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                           'config': {'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_12',
#                                    'trainable': True,
#                                    'units': 10,
#                                    'use_bias': True}}],
#             'name': 'sequential_3'},
#  'keras_version': '2.2.4-tf'}

# %%
fresh_model = tf.keras.models.model_from_json(json_string)

# %%
# %pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading PyYAML-5.3-cp37-cp37m-win_amd64.whl (215 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
yaml_string = model.to_yaml()
print(yaml_string)
# Out:
# backend: tensorflow
# class_name: Sequential
# config:
#   layers:
#   - class_name: Dense
#     config:
#       activation: relu
#       activity_regularizer: null
#       batch_input_shape: !!python/tuple
#       - null
#       - 32
#       bias_constraint: null
#       bias_initializer:
#         class_name: Zeros
#         config: {}
#       bias_regularizer: null
#       dtype: float32
#       kernel_constraint: null
#       kernel_initializer:
#         class_name: GlorotUniform
#         config:
#           seed: null
#       kernel_regularizer: null
#       name: dense_11
#       trainable: true
#       units: 64
#       use_bias: true
#   - class_name: Dense
#     config:
#       activation: softmax
#       activity_regularizer: null
#       bias_constraint: null
#       bias_initializer:
#         class_name: Zeros
#         config: {}
#       bias_regularizer: null
#       dtype: float32
#       kernel_constraint: null
#       kernel_initializer:
#         class_name: GlorotUniform
#         config:
#           seed: null
#       kernel_regularizer: null
#       name: dense_12
#       trainable: true
#       units: 10
#       use_bias: true
#   name: sequential_3
# keras_version: 2.2.4-tf

# %%
fresh_model = tf.keras.models.model_from_yaml(yaml_string)
# Out:
# C:\Users\pc\Anaconda3\envs\tf2.0-gpu\lib\site-packages\tensorflow\python\keras\saving\model_config.py:76: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(yaml_string)

# %%
# Create a simple model
model = tf.keras.Sequential([
    layers.Dense(10, activation = 'softmax', input_shape=(32,)),
    layers.Dense(10, activation = 'softmax')
])
model.compile(optimizer = 'rmsprop',
             loss = 'categorical_crossentropy',
             metrics=['accuracy'])
model.fit(data, labels, batch_size = 32, epochs = 5)

# Save entire model to a HDF5 file
model.save('my_model.h5')

# Recreate the exact same model, including weights and optimizer.
model = tf.keras.models.load_model('my_model.h5')
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 178us/sample - loss: 11.4111 - accuracy: 0.0900
# Epoch 2/5
# 1000/1000 [==============================] - 0s 77us/sample - loss: 11.3952 - accuracy: 0.0870
# Epoch 3/5
# 1000/1000 [==============================] - 0s 60us/sample - loss: 11.3902 - accuracy: 0.1110
# Epoch 4/5
# 1000/1000 [==============================] - 0s 74us/sample - loss: 11.3887 - accuracy: 0.1130
# Epoch 5/5
# 1000/1000 [==============================] - 0s 74us/sample - loss: 11.3879 - accuracy: 0.0960

# %%
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    model = tf.keras.Sequential()
    model.add(layers.Dense(16, activation = 'relu', input_shape=(10,)))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    optimizer = tf.keras.optimizers.SGD(0.2)
    
    model.compile(loss='binary_crossentropy',optimizer = optimizer)
    
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 16)                176
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = np.random.random((1024,10))
y = np.random.randint(2, size=(1024,1))
x = tf.cast(x, tf.float32)
dataset = tf.data.Dataset.from_tensor_slices((x,y))
dataset = dataset.shuffle(buffer_size=1024).batch(32)

model.fit(dataset, epochs=1)
# Out:
# Train on 32 steps
# 32/32 [==============================] - 0s 15ms/step - loss: 0.7020

# %%
model = tf.keras.models.load_model('my_model.h5')
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.Accuracy(name='accuracy')])
# Out:
# WARNING:tensorflow:From C:\Users\pc\Anaconda3\envs\tf2.0-gpu\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
